# %% [markdown]
# # Comparison Operator

# %% [markdown]
# == , != , >= , <= , < , >

# %% [markdown]
# # Logical Operator

# %% [markdown]
# and , or , not

# %% [markdown]
# # Arithmetic Operator

# %% [markdown]
# + , - , * , / , // , % , **

# %% [markdown]
# # Assignment Operator

# %% [markdown]
# = , += , -= , /= , //= , %= , **=
