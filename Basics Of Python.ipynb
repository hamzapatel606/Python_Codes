# %% [markdown]
# Q. What is **Python** ?

# %% [markdown]
# Python is genral purpose programming language. Which is devloped by
#   "**Guido Van Rossum**" in 20 Feb 1991.

# %% [markdown]
# It composed from different languages like

# %% [markdown]
# **Functional programming** from **C** language

# %% [markdown]
# **Object Oriented Programming** from **C++** language

# %% [markdown]
# **Scripting feature** from **Shell Script**.

# %% [markdown]
# Q. Use of **Python** ?

# %% [markdown]
# It used almost everywhere for eg.

# %% [markdown]
# >> Developing  >> Desktop application  >> Web application  >> Database  >> Network programming  >> Game developement  >> Data analysis >> AI  >> ML  >> DL

# %% [markdown]
# Q. What are the key features of **Python** ?

# %% [markdown]
# Easy to code

# %% [markdown]
# Platform independent & Portable

# %% [markdown]
# Free and open source

# %% [markdown]
# Object Oriented Language

# %% [markdown]
# GUI programming support

# %% [markdown]
# High level laguage

# %% [markdown]
# Extensible feature

# %% [markdown]
# Dynamically typed language
